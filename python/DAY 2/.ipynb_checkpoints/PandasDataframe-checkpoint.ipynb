# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df_2016 = pd.read_csv("AAPL-2016.csv", parse_dates =True, usecols=["Date", "Volume"])

# %%
df_2016.plot()
# Out:
# <Axes: >
